# %%
# to use this, copy-paste the text into the file below
log_text = """
Experiment with the following hyperparameters:
        Dataset: NBA, Epochs: 500, Test epochs: 500, Batch size: 1000
        Device: cuda, Seed: 42, N Runs: 5, N Tests: 1
        Augmentation model g hyperparameters: {'n_hidden': 64, 'temperature': 1.0, 'nlayer': 1, 'dropout': 0.1, 'mlpx_dropout': 0.1}
        Encoder model f hyperparameters: {'n_hidden': 64, 'out_feats': 64, 'dropout': 0.1, 'nlayer': 2}
        Adversary model k hyperparameters: {'n_hidden': 64, 'out_feats': 64, 'dropout': 0.1, 'nlayer': 2, 'nclass': 1}
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 0.1
Start training
Training time: 18.83
Average time per epoch: 0.0377
Run 0 results: {'acc': {'mean': 0.7163120567375887, 'std': 0.0}, 'dp': {'mean': 0.15440115440115443, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 13.86
Average time per epoch: 0.0277
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.012265512265512257, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 15.45
Average time per epoch: 0.0309
Run 2 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0050505050505050275, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 13.21
Average time per epoch: 0.0264
Run 3 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.05555555555555558, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Training time: 11.43
Average time per epoch: 0.0229
Run 4 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.025974025974025983, 'std': 0.0}, 'eo': {'mean': 0.02819548872180444, 'std': 0.0}}
Average training time per run: 14.56
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 0.1
Average results: {'acc': {'mean': 0.6836879432624113, 'std': 0.02269503546099294}, 'dp': {'mean': 0.05064935064935065, 'std': 0.054680806587304745}, 'eo': {'mean': 0.042293233082706785, 'std': 0.02166144404644805}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 1.0
Start training
Training time: 10.66
Average time per epoch: 0.0213
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0021645021645021467, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Training time: 17.27
Average time per epoch: 0.0345
Run 1 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.056277056277056314, 'std': 0.0}, 'eo': {'mean': 0.09962406015037595, 'std': 0.0}}
Training time: 10.84
Average time per epoch: 0.0217
Run 2 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.02819548872180444, 'std': 0.0}}
Training time: 10.37
Average time per epoch: 0.0207
Run 3 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.010822510822510845, 'std': 0.0}, 'eo': {'mean': 0.06296992481203012, 'std': 0.0}}
Training time: 13.56
Average time per epoch: 0.0271
Run 4 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.13852813852813856, 'std': 0.0}, 'eo': {'mean': 0.16823308270676696, 'std': 0.0}}
Average training time per run: 12.54
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 1.0
Average results: {'acc': {'mean': 0.6808510638297872, 'std': 0.008971000454378394}, 'dp': {'mean': 0.042424242424242434, 'std': 0.051958873331764396}, 'eo': {'mean': 0.0731203007518797, 'std': 0.057092751083148034}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 10.0
Start training
Training time: 19.73
Average time per epoch: 0.0395
Run 0 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.0670995670995671, 'std': 0.0}, 'eo': {'mean': 0.010338345864661647, 'std': 0.0}}
Training time: 15.87
Average time per epoch: 0.0317
Run 1 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.011544011544011523, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 10.50
Average time per epoch: 0.0210
Run 2 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.06390977443609025, 'std': 0.0}}
Training time: 10.28
Average time per epoch: 0.0206
Run 3 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.020923520923520955, 'std': 0.0}, 'eo': {'mean': 0.045112781954887216, 'std': 0.0}}
Training time: 17.01
Average time per epoch: 0.0340
Run 4 results: {'acc': {'mean': 0.6453900709219857, 'std': 0.0}, 'dp': {'mean': 0.046176046176046204, 'std': 0.0}, 'eo': {'mean': 0.02819548872180444, 'std': 0.0}}
Average training time per run: 14.68
alpha: 0.1, beta: 1.0, gamma: 0.1, lam: 10.0
Average results: {'acc': {'mean': 0.6666666666666666, 'std': 0.014184397163120588}, 'dp': {'mean': 0.03362193362193363, 'std': 0.020266851241130375}, 'eo': {'mean': 0.042481203007518786, 'std': 0.020993808799608608}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 0.1
Start training
Training time: 10.30
Average time per epoch: 0.0206
Run 0 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.045454545454545414, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 14.01
Average time per epoch: 0.0280
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.012265512265512257, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 13.03
Average time per epoch: 0.0261
Run 2 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.02525252525252525, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Training time: 15.19
Average time per epoch: 0.0304
Run 3 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.034632034632034625, 'std': 0.0}, 'eo': {'mean': 0.045112781954887216, 'std': 0.0}}
Training time: 12.01
Average time per epoch: 0.0240
Run 4 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.011544011544011523, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Average training time per run: 12.91
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 0.1
Average results: {'acc': {'mean': 0.6709219858156028, 'std': 0.01713907230297105}, 'dp': {'mean': 0.025829725829725814, 'std': 0.01304620150337166}, 'eo': {'mean': 0.03402255639097744, 'std': 0.02836664841046752}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 1.0
Start training
Training time: 11.99
Average time per epoch: 0.0240
Run 0 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.038961038961038974, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 15.03
Average time per epoch: 0.0301
Run 1 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.06060606060606061, 'std': 0.0}, 'eo': {'mean': 0.07988721804511284, 'std': 0.0}}
Training time: 17.06
Average time per epoch: 0.0341
Run 2 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.027417027417027395, 'std': 0.0}, 'eo': {'mean': 0.043233082706766957, 'std': 0.0}}
Training time: 13.80
Average time per epoch: 0.0276
Run 3 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.008658008658008698, 'std': 0.0}, 'eo': {'mean': 0.005639097744360888, 'std': 0.0}}
Training time: 15.06
Average time per epoch: 0.0301
Run 4 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.021645021645021634, 'std': 0.0}, 'eo': {'mean': 0.011278195488721887, 'std': 0.0}}
Average training time per run: 14.59
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 1.0
Average results: {'acc': {'mean': 0.676595744680851, 'std': 0.010614630884465098}, 'dp': {'mean': 0.03145743145743146, 'std': 0.017540630763662614}, 'eo': {'mean': 0.03740601503759403, 'std': 0.026915823037095873}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 10.0
Start training
Training time: 16.90
Average time per epoch: 0.0338
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.01803751803751802, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Training time: 13.68
Average time per epoch: 0.0274
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.012265512265512257, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 15.63
Average time per epoch: 0.0313
Run 2 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.005772005772005817, 'std': 0.0}, 'eo': {'mean': 0.046052631578947345, 'std': 0.0}}
Training time: 16.74
Average time per epoch: 0.0335
Run 3 results: {'acc': {'mean': 0.7163120567375887, 'std': 0.0}, 'dp': {'mean': 0.01875901875901881, 'std': 0.0}, 'eo': {'mean': 0.012218045112781906, 'std': 0.0}}
Training time: 10.04
Average time per epoch: 0.0201
Run 4 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.021645021645021634, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Average training time per run: 14.60
alpha: 0.1, beta: 1.0, gamma: 1.0, lam: 10.0
Average results: {'acc': {'mean': 0.6950354609929079, 'std': 0.014184397163120588}, 'dp': {'mean': 0.015295815295815307, 'std': 0.0056517044812600566}, 'eo': {'mean': 0.020112781954887193, 'std': 0.015381407928931426}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 0.1
Start training
Training time: 14.89
Average time per epoch: 0.0298
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.02886002886002892, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 17.92
Average time per epoch: 0.0358
Run 1 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.06277056277056275, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 11.65
Average time per epoch: 0.0233
Run 2 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.01875901875901881, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 18.34
Average time per epoch: 0.0367
Run 3 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.015151515151515138, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 18.47
Average time per epoch: 0.0369
Run 4 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.012265512265512257, 'std': 0.0}, 'eo': {'mean': 0.06390977443609025, 'std': 0.0}}
Average training time per run: 16.25
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 0.1
Average results: {'acc': {'mean': 0.6780141843971631, 'std': 0.009620326217198976}, 'dp': {'mean': 0.027561327561327575, 'std': 0.01847605433497168}, 'eo': {'mean': 0.050375939849624095, 'std': 0.013165948126193571}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 1.0
Start training
Training time: 13.23
Average time per epoch: 0.0265
Run 0 results: {'acc': {'mean': 0.6382978723404256, 'std': 0.0}, 'dp': {'mean': 0.04256854256854259, 'std': 0.0}, 'eo': {'mean': 0.11654135338345872, 'std': 0.0}}
Training time: 19.98
Average time per epoch: 0.0400
Run 1 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.0050505050505050275, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 16.19
Average time per epoch: 0.0324
Run 2 results: {'acc': {'mean': 0.7163120567375887, 'std': 0.0}, 'dp': {'mean': 0.0735930735930736, 'std': 0.0}, 'eo': {'mean': 0.08176691729323304, 'std': 0.0}}
Training time: 11.09
Average time per epoch: 0.0222
Run 3 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.09956709956709964, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 15.51
Average time per epoch: 0.0310
Run 4 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.031746031746031744, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Average training time per run: 15.20
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 1.0
Average results: {'acc': {'mean': 0.675177304964539, 'std': 0.0274313185898067}, 'dp': {'mean': 0.05050505050505052, 'std': 0.03292763615501974}, 'eo': {'mean': 0.07406015037593987, 'std': 0.02995393791713771}}
-----------------------------------------------
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 10.0
Start training
Training time: 18.27
Average time per epoch: 0.0365
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.056277056277056314, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 13.07
Average time per epoch: 0.0261
Run 1 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.06926406926406925, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 10.54
Average time per epoch: 0.0211
Run 2 results: {'acc': {'mean': 0.6170212765957447, 'std': 0.0}, 'dp': {'mean': 0.03246753246753248, 'std': 0.0}, 'eo': {'mean': 0.08082706766917291, 'std': 0.0}}
Training time: 15.72
Average time per epoch: 0.0314
Run 3 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.03007518796992481, 'std': 0.0}}
Training time: 16.01
Average time per epoch: 0.0320
Run 4 results: {'acc': {'mean': 0.7092198581560284, 'std': 0.0}, 'dp': {'mean': 0.056277056277056314, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Average training time per run: 14.72
alpha: 0.1, beta: 1.0, gamma: 10.0, lam: 10.0
Average results: {'acc': {'mean': 0.672340425531915, 'std': 0.03338610580408461}, 'dp': {'mean': 0.04733044733044735, 'std': 0.01723526142674302}, 'eo': {'mean': 0.046804511278195515, 'std': 0.01870654933026274}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 0.1
Start training
Training time: 18.85
Average time per epoch: 0.0377
Run 0 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.028860028860028863, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 17.51
Average time per epoch: 0.0350
Run 1 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.03607503607503609, 'std': 0.0}, 'eo': {'mean': 0.08176691729323304, 'std': 0.0}}
Training time: 13.58
Average time per epoch: 0.0272
Run 2 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.06204906204906202, 'std': 0.0}, 'eo': {'mean': 0.06015037593984962, 'std': 0.0}}
Training time: 15.54
Average time per epoch: 0.0311
Run 3 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.08082706766917291, 'std': 0.0}}
Training time: 13.17
Average time per epoch: 0.0263
Run 4 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.009379509379509376, 'std': 0.0}, 'eo': {'mean': 0.08082706766917291, 'std': 0.0}}
Average training time per run: 15.73
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 0.1
Average results: {'acc': {'mean': 0.6723404255319149, 'std': 0.013752283283450597}, 'dp': {'mean': 0.02813852813852813, 'std': 0.020650555636361694}, 'eo': {'mean': 0.06654135338345864, 'std': 0.02039625267226395}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 1.0
Start training
Training time: 16.04
Average time per epoch: 0.0321
Run 0 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.028860028860028863, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 16.33
Average time per epoch: 0.0327
Run 1 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.09962406015037595, 'std': 0.0}}
Training time: 14.63
Average time per epoch: 0.0293
Run 2 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.11255411255411252, 'std': 0.0}, 'eo': {'mean': 0.11372180451127811, 'std': 0.0}}
Training time: 16.97
Average time per epoch: 0.0339
Run 3 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.010822510822510845, 'std': 0.0}, 'eo': {'mean': 0.06296992481203012, 'std': 0.0}}
Training time: 14.00
Average time per epoch: 0.0280
Run 4 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.04689754689754688, 'std': 0.0}, 'eo': {'mean': 0.09774436090225563, 'std': 0.0}}
Average training time per run: 15.59
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 1.0
Average results: {'acc': {'mean': 0.6695035460992907, 'std': 0.015921946326697644}, 'dp': {'mean': 0.0443001443001443, 'std': 0.03607099544470768}, 'eo': {'mean': 0.0806390977443609, 'std': 0.030699580507151113}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 10.0
Start training
Training time: 15.52
Average time per epoch: 0.0310
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.03823953823953824, 'std': 0.0}, 'eo': {'mean': 0.042293233082706716, 'std': 0.0}}
Training time: 14.95
Average time per epoch: 0.0299
Run 1 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.06637806637806642, 'std': 0.0}, 'eo': {'mean': 0.09962406015037595, 'std': 0.0}}
Training time: 17.35
Average time per epoch: 0.0347
Run 2 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.031746031746031744, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Training time: 19.32
Average time per epoch: 0.0386
Run 3 results: {'acc': {'mean': 0.6453900709219857, 'std': 0.0}, 'dp': {'mean': 0.025974025974025983, 'std': 0.0}, 'eo': {'mean': 0.08082706766917291, 'std': 0.0}}
Training time: 15.75
Average time per epoch: 0.0315
Run 4 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.0007215007215007341, 'std': 0.0}, 'eo': {'mean': 0.045112781954887216, 'std': 0.0}}
Average training time per run: 16.58
alpha: 1.0, beta: 1.0, gamma: 0.1, lam: 10.0
Average results: {'acc': {'mean': 0.6680851063829787, 'std': 0.015144791846852945}, 'dp': {'mean': 0.03261183261183263, 'std': 0.021135907690769788}, 'eo': {'mean': 0.05845864661654134, 'std': 0.027538716649342012}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 0.1
Start training
Training time: 15.46
Average time per epoch: 0.0309
Run 0 results: {'acc': {'mean': 0.7092198581560284, 'std': 0.0}, 'dp': {'mean': 0.12409812409812415, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 17.68
Average time per epoch: 0.0354
Run 1 results: {'acc': {'mean': 0.7092198581560284, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 19.49
Average time per epoch: 0.0390
Run 2 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.0526695526695527, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 14.63
Average time per epoch: 0.0293
Run 3 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.06390977443609025, 'std': 0.0}}
Training time: 11.75
Average time per epoch: 0.0235
Run 4 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.02886002886002892, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Average training time per run: 15.80
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 0.1
Average results: {'acc': {'mean': 0.6907801418439716, 'std': 0.019858156028368823}, 'dp': {'mean': 0.0500721500721501, 'std': 0.038656820951005776}, 'eo': {'mean': 0.050375939849624095, 'std': 0.013165948126193571}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 1.0
Start training
Training time: 13.03
Average time per epoch: 0.0261
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.01803751803751802, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Training time: 14.33
Average time per epoch: 0.0287
Run 1 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.012987012987012991, 'std': 0.0}, 'eo': {'mean': 0.007518796992481258, 'std': 0.0}}
Training time: 10.16
Average time per epoch: 0.0203
Run 2 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.01875901875901881, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 12.99
Average time per epoch: 0.0260
Run 3 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.020923520923520955, 'std': 0.0}, 'eo': {'mean': 0.045112781954887216, 'std': 0.0}}
Training time: 17.67
Average time per epoch: 0.0353
Run 4 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.03318903318903321, 'std': 0.0}, 'eo': {'mean': 0.010338345864661647, 'std': 0.0}}
Average training time per run: 13.64
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 1.0
Average results: {'acc': {'mean': 0.6808510638297873, 'std': 0.006343455255318561}, 'dp': {'mean': 0.020779220779220797, 'std': 0.006728163478715601}, 'eo': {'mean': 0.023308270676691743, 'std': 0.013624902461970007}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 10.0
Start training
Training time: 13.91
Average time per epoch: 0.0278
Run 0 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.005050505050505083, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 15.53
Average time per epoch: 0.0311
Run 1 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.059884559884559874, 'std': 0.0}, 'eo': {'mean': 0.06390977443609025, 'std': 0.0}}
Training time: 10.63
Average time per epoch: 0.0213
Run 2 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.031746031746031744, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Training time: 12.95
Average time per epoch: 0.0259
Run 3 results: {'acc': {'mean': 0.7163120567375887, 'std': 0.0}, 'dp': {'mean': 0.059884559884559874, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 15.03
Average time per epoch: 0.0301
Run 4 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.04545454545454547, 'std': 0.0}, 'eo': {'mean': 0.05921052631578949, 'std': 0.0}}
Average training time per run: 13.61
alpha: 1.0, beta: 1.0, gamma: 1.0, lam: 10.0
Average results: {'acc': {'mean': 0.6851063829787234, 'std': 0.01713907230297105}, 'dp': {'mean': 0.04040404040404041, 'std': 0.020539340085030965}, 'eo': {'mean': 0.044736842105263186, 'std': 0.01573343079536961}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 0.1
Start training
Training time: 16.00
Average time per epoch: 0.0320
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 16.77
Average time per epoch: 0.0335
Run 1 results: {'acc': {'mean': 0.7163120567375887, 'std': 0.0}, 'dp': {'mean': 0.08658008658008659, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 18.27
Average time per epoch: 0.0365
Run 2 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.01875901875901881, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 9.96
Average time per epoch: 0.0199
Run 3 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.021645021645021578, 'std': 0.0}, 'eo': {'mean': 0.03007518796992481, 'std': 0.0}}
Training time: 14.41
Average time per epoch: 0.0288
Run 4 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.008658008658008698, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Average training time per run: 15.08
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 0.1
Average results: {'acc': {'mean': 0.6921985815602837, 'std': 0.013154068787937187}, 'dp': {'mean': 0.03160173160173161, 'std': 0.027922730434485985}, 'eo': {'mean': 0.04360902255639101, 'std': 0.02069889443612744}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 1.0
Start training
Training time: 15.48
Average time per epoch: 0.0310
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.032467532467532534, 'std': 0.0}, 'eo': {'mean': 0.03007518796992481, 'std': 0.0}}
Training time: 18.70
Average time per epoch: 0.0374
Run 1 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.045454545454545414, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 15.73
Average time per epoch: 0.0315
Run 2 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0901875901875902, 'std': 0.0}, 'eo': {'mean': 0.08176691729323304, 'std': 0.0}}
Training time: 11.26
Average time per epoch: 0.0225
Run 3 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.032467532467532534, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 11.45
Average time per epoch: 0.0229
Run 4 results: {'acc': {'mean': 0.6312056737588653, 'std': 0.0}, 'dp': {'mean': 0.020923520923520955, 'std': 0.0}, 'eo': {'mean': 0.008458646616541277, 'std': 0.0}}
Average training time per run: 14.52
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 1.0
Average results: {'acc': {'mean': 0.6695035460992907, 'std': 0.02132382465017433}, 'dp': {'mean': 0.044300144300144326, 'std': 0.024221801164048803}, 'eo': {'mean': 0.05357142857142856, 'std': 0.029523846756085836}}
-----------------------------------------------
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 10.0
Start training
Training time: 14.38
Average time per epoch: 0.0288
Run 0 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.025252525252525304, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 16.32
Average time per epoch: 0.0326
Run 1 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.021645021645021578, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 13.80
Average time per epoch: 0.0276
Run 2 results: {'acc': {'mean': 0.5957446808510638, 'std': 0.0}, 'dp': {'mean': 0.0007215007215006786, 'std': 0.0}, 'eo': {'mean': 0.005639097744360888, 'std': 0.0}}
Training time: 14.62
Average time per epoch: 0.0292
Run 3 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.0526695526695527, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 12.24
Average time per epoch: 0.0245
Run 4 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Average training time per run: 14.27
alpha: 1.0, beta: 1.0, gamma: 10.0, lam: 10.0
Average results: {'acc': {'mean': 0.6638297872340425, 'std': 0.03768888015769199}, 'dp': {'mean': 0.02092352092352091, 'std': 0.01849632922847257}, 'eo': {'mean': 0.044924812030075215, 'std': 0.02753871664934203}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 0.1
Start training
Training time: 14.68
Average time per epoch: 0.0294
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.024531024531024515, 'std': 0.0}, 'eo': {'mean': 0.06015037593984962, 'std': 0.0}}
Training time: 14.49
Average time per epoch: 0.0290
Run 1 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.04256854256854259, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 14.78
Average time per epoch: 0.0296
Run 2 results: {'acc': {'mean': 0.6382978723404256, 'std': 0.0}, 'dp': {'mean': 0.044733044733044736, 'std': 0.0}, 'eo': {'mean': 0.06109022556390975, 'std': 0.0}}
Training time: 14.65
Average time per epoch: 0.0293
Run 3 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.05844155844155846, 'std': 0.0}, 'eo': {'mean': 0.02819548872180444, 'std': 0.0}}
Training time: 17.16
Average time per epoch: 0.0343
Run 4 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.025974025974025983, 'std': 0.0}, 'eo': {'mean': 0.042293233082706716, 'std': 0.0}}
Average training time per run: 15.15
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 0.1
Average results: {'acc': {'mean': 0.6709219858156028, 'std': 0.019858156028368785}, 'dp': {'mean': 0.03924963924963926, 'std': 0.01266721867091184}, 'eo': {'mean': 0.044172932330827044, 'std': 0.014327698496360536}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 1.0
Start training
Training time: 11.51
Average time per epoch: 0.0230
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.011544011544011523, 'std': 0.0}, 'eo': {'mean': 0.011278195488721887, 'std': 0.0}}
Training time: 13.36
Average time per epoch: 0.0267
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.012265512265512257, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 10.01
Average time per epoch: 0.0200
Run 2 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.07215007215007213, 'std': 0.0}, 'eo': {'mean': 0.07800751879699241, 'std': 0.0}}
Training time: 13.37
Average time per epoch: 0.0267
Run 3 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.06296992481203012, 'std': 0.0}}
Training time: 10.76
Average time per epoch: 0.0215
Run 4 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.07800751879699241, 'std': 0.0}}
Average training time per run: 11.80
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 1.0
Average results: {'acc': {'mean': 0.6680851063829787, 'std': 0.020259371428490384}, 'dp': {'mean': 0.0209235209235209, 'std': 0.025837383082271737}, 'eo': {'mean': 0.0518796992481203, 'std': 0.02703370885465679}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 10.0
Start training
Training time: 11.09
Average time per epoch: 0.0222
Run 0 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.05194805194805191, 'std': 0.0}, 'eo': {'mean': 0.042293233082706716, 'std': 0.0}}
Training time: 13.49
Average time per epoch: 0.0270
Run 1 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.022366522366522368, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 17.41
Average time per epoch: 0.0348
Run 2 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.02525252525252525, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Training time: 18.43
Average time per epoch: 0.0369
Run 3 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.05844155844155846, 'std': 0.0}, 'eo': {'mean': 0.010338345864661647, 'std': 0.0}}
Training time: 14.09
Average time per epoch: 0.0282
Run 4 results: {'acc': {'mean': 0.6312056737588653, 'std': 0.0}, 'dp': {'mean': 0.0007215007215007341, 'std': 0.0}, 'eo': {'mean': 0.009398496240601517, 'std': 0.0}}
Average training time per run: 14.90
alpha: 10.0, beta: 1.0, gamma: 0.1, lam: 10.0
Average results: {'acc': {'mean': 0.6652482269503546, 'std': 0.022156736669238734}, 'dp': {'mean': 0.031746031746031744, 'std': 0.021040128867799327}, 'eo': {'mean': 0.019548872180451114, 'std': 0.013894525272613773}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 0.1
Start training
Training time: 16.85
Average time per epoch: 0.0337
Run 0 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.07287157287157292, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 18.42
Average time per epoch: 0.0368
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.03246753246753248, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 18.80
Average time per epoch: 0.0376
Run 2 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.04978354978354976, 'std': 0.0}, 'eo': {'mean': 0.046052631578947345, 'std': 0.0}}
Training time: 13.72
Average time per epoch: 0.0274
Run 3 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.024531024531024515, 'std': 0.0}, 'eo': {'mean': 0.045112781954887216, 'std': 0.0}}
Training time: 12.58
Average time per epoch: 0.0252
Run 4 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.031746031746031744, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Average training time per run: 16.08
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 0.1
Average results: {'acc': {'mean': 0.6780141843971631, 'std': 0.01713907230297105}, 'dp': {'mean': 0.042279942279942286, 'std': 0.017403578520200618}, 'eo': {'mean': 0.04548872180451129, 'std': 0.012812325705227046}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 1.0
Start training
Training time: 12.88
Average time per epoch: 0.0258
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.011544011544011523, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 13.24
Average time per epoch: 0.0265
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.0526695526695527, 'std': 0.0}, 'eo': {'mean': 0.13533834586466165, 'std': 0.0}}
Training time: 9.93
Average time per epoch: 0.0199
Run 2 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.019480519480519487, 'std': 0.0}, 'eo': {'mean': 0.010338345864661647, 'std': 0.0}}
Training time: 14.04
Average time per epoch: 0.0281
Run 3 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.034632034632034625, 'std': 0.0}, 'eo': {'mean': 0.06296992481203012, 'std': 0.0}}
Training time: 16.85
Average time per epoch: 0.0337
Run 4 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.0014430014430014126, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Average training time per run: 13.39
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 1.0
Average results: {'acc': {'mean': 0.6865248226950355, 'std': 0.01134751773049647}, 'dp': {'mean': 0.02395382395382395, 'std': 0.017996490135773452}, 'eo': {'mean': 0.053383458646616554, 'std': 0.044356123101808156}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 10.0
Start training
Training time: 15.70
Average time per epoch: 0.0314
Run 0 results: {'acc': {'mean': 0.6950354609929078, 'std': 0.0}, 'dp': {'mean': 0.07215007215007213, 'std': 0.0}, 'eo': {'mean': 0.024436090225563922, 'std': 0.0}}
Training time: 14.85
Average time per epoch: 0.0297
Run 1 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.10678210678210681, 'std': 0.0}, 'eo': {'mean': 0.15319548872180444, 'std': 0.0}}
Training time: 15.33
Average time per epoch: 0.0307
Run 2 results: {'acc': {'mean': 0.7092198581560284, 'std': 0.0}, 'dp': {'mean': 0.0901875901875902, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 15.43
Average time per epoch: 0.0309
Run 3 results: {'acc': {'mean': 0.6666666666666666, 'std': 0.0}, 'dp': {'mean': 0.03823953823953824, 'std': 0.0}, 'eo': {'mean': 0.010338345864661647, 'std': 0.0}}
Training time: 17.11
Average time per epoch: 0.0342
Run 4 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.021645021645021634, 'std': 0.0}, 'eo': {'mean': 0.006578947368421018, 'std': 0.0}}
Average training time per run: 15.68
alpha: 10.0, beta: 1.0, gamma: 1.0, lam: 10.0
Average results: {'acc': {'mean': 0.6893617021276596, 'std': 0.01641962681246843}, 'dp': {'mean': 0.0658008658008658, 'std': 0.03169811417103358}, 'eo': {'mean': 0.048308270676691724, 'std': 0.05432493428375351}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 0.1
Start training
Training time: 9.91
Average time per epoch: 0.0198
Run 0 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.03246753246753248, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 13.57
Average time per epoch: 0.0271
Run 1 results: {'acc': {'mean': 0.7234042553191489, 'std': 0.0}, 'dp': {'mean': 0.2121212121212121, 'std': 0.0}, 'eo': {'mean': 0.22368421052631582, 'std': 0.0}}
Training time: 13.13
Average time per epoch: 0.0263
Run 2 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0043290043290042934, 'std': 0.0}, 'eo': {'mean': 0.042293233082706716, 'std': 0.0}}
Training time: 12.70
Average time per epoch: 0.0254
Run 3 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.015151515151515138, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 13.67
Average time per epoch: 0.0273
Run 4 results: {'acc': {'mean': 0.7021276595744681, 'std': 0.0}, 'dp': {'mean': 0.0014430014430014126, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Average training time per run: 12.60
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 0.1
Average results: {'acc': {'mean': 0.6950354609929079, 'std': 0.01617270106523598}, 'dp': {'mean': 0.05310245310245308, 'std': 0.08025034281776373}, 'eo': {'mean': 0.08139097744360904, 'std': 0.0720604226023201}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 1.0
Start training
Training time: 11.72
Average time per epoch: 0.0234
Run 0 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.025974025974025983, 'std': 0.0}, 'eo': {'mean': 0.13439849624060152, 'std': 0.0}}
Training time: 10.64
Average time per epoch: 0.0213
Run 1 results: {'acc': {'mean': 0.6737588652482269, 'std': 0.0}, 'dp': {'mean': 0.045454545454545414, 'std': 0.0}, 'eo': {'mean': 0.08270676691729328, 'std': 0.0}}
Training time: 12.23
Average time per epoch: 0.0245
Run 2 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.08946608946608947, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 10.14
Average time per epoch: 0.0203
Run 3 results: {'acc': {'mean': 0.652482269503546, 'std': 0.0}, 'dp': {'mean': 0.02813852813852813, 'std': 0.0}, 'eo': {'mean': 0.03007518796992481, 'std': 0.0}}
Training time: 14.89
Average time per epoch: 0.0298
Run 4 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.03679653679653677, 'std': 0.0}, 'eo': {'mean': 0.025375939849624052, 'std': 0.0}}
Average training time per run: 11.92
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 1.0
Average results: {'acc': {'mean': 0.6695035460992907, 'std': 0.014603730696435483}, 'dp': {'mean': 0.04516594516594515, 'std': 0.02319868860297426}, 'eo': {'mean': 0.06748120300751881, 'std': 0.03972085166347145}}
-----------------------------------------------
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 10.0
Start training
Training time: 15.01
Average time per epoch: 0.0300
Run 0 results: {'acc': {'mean': 0.6808510638297872, 'std': 0.0}, 'dp': {'mean': 0.0050505050505050275, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 13.39
Average time per epoch: 0.0268
Run 1 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.028860028860028863, 'std': 0.0}, 'eo': {'mean': 0.06484962406015038, 'std': 0.0}}
Training time: 15.91
Average time per epoch: 0.0318
Run 2 results: {'acc': {'mean': 0.6879432624113475, 'std': 0.0}, 'dp': {'mean': 0.03246753246753248, 'std': 0.0}, 'eo': {'mean': 0.02913533834586468, 'std': 0.0}}
Training time: 14.89
Average time per epoch: 0.0298
Run 3 results: {'acc': {'mean': 0.6453900709219857, 'std': 0.0}, 'dp': {'mean': 0.011544011544011523, 'std': 0.0}, 'eo': {'mean': 0.046992481203007586, 'std': 0.0}}
Training time: 15.47
Average time per epoch: 0.0309
Run 4 results: {'acc': {'mean': 0.6595744680851063, 'std': 0.0}, 'dp': {'mean': 0.014430014430014404, 'std': 0.0}, 'eo': {'mean': 0.007518796992481258, 'std': 0.0}}
Average training time per run: 14.93
alpha: 10.0, beta: 1.0, gamma: 10.0, lam: 10.0
Average results: {'acc': {'mean': 0.6723404255319149, 'std': 0.017021276595744705}, 'dp': {'mean': 0.01847041847041846, 'std': 0.010471458907086152}, 'eo': {'mean': 0.0390977443609023, 'std': 0.019412843677126226}}
-----------------------------------------------
Grid Search Results:
 Best Accuracy: {'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6950354609929079, 'std': 0.014184397163120588}, 'dp': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}, 'eo': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}}
Best DP: {'alpha': 10.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6893617021276596, 'std': 0.01641962681246843}, 'dp': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}, 'eo': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}}
Best EO: {'alpha': 10.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6893617021276596, 'std': 0.01641962681246843}, 'dp': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}, 'eo': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}}



Pareto Front (Accuracy - DP):
 [{'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6950354609929079, 'std': 0.014184397163120588}, 'dp': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}, 'eo': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}}]
Pareto Front (Accuracy - EO):


 [{'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6950354609929079, 'std': 0.014184397163120588}, 'dp': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}, 'eo': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}}]
All Results:
 [{'alpha': 0.1, 'beta': 1.0, 'gamma': 0.1, 'lam': 0.1, 'accuracy': {'mean': 0.6836879432624113, 'std': 0.02269503546099294}, 'dp': {'mean': 0.05064935064935065, 'std': 0.02166144404644805}, 'eo': {'mean': 0.05064935064935065, 'std': 0.02166144404644805}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 0.1, 'lam': 1.0, 'accuracy': {'mean': 0.6808510638297872, 'std': 0.008971000454378394}, 'dp': {'mean': 0.042424242424242434, 'std': 0.057092751083148034}, 'eo': {'mean': 0.042424242424242434, 'std': 0.057092751083148034}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 0.1, 'lam': 10.0, 'accuracy': {'mean': 0.6666666666666666, 'std': 0.014184397163120588}, 'dp': {'mean': 0.03362193362193363, 'std': 0.020993808799608608}, 'eo': {'mean': 0.03362193362193363, 'std': 0.020993808799608608}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 0.1, 'accuracy': {'mean': 0.6709219858156028, 'std': 0.01713907230297105}, 'dp': {'mean': 0.025829725829725814, 'std': 0.02836664841046752}, 'eo': {'mean': 0.025829725829725814, 'std': 0.02836664841046752}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 1.0, 'accuracy': {'mean': 0.676595744680851, 'std': 0.010614630884465098}, 'dp': {'mean': 0.03145743145743146, 'std': 0.026915823037095873}, 'eo': {'mean': 0.03145743145743146, 'std': 0.026915823037095873}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6950354609929079, 'std': 0.014184397163120588}, 'dp': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}, 'eo': {'mean': 0.015295815295815307, 'std': 0.015381407928931426}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 10.0, 'lam': 0.1, 'accuracy': {'mean': 0.6780141843971631, 'std': 0.009620326217198976}, 'dp': {'mean': 0.027561327561327575, 'std': 0.013165948126193571}, 'eo': {'mean': 0.027561327561327575, 'std': 0.013165948126193571}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 10.0, 'lam': 1.0, 'accuracy': {'mean': 0.675177304964539, 'std': 0.0274313185898067}, 'dp': {'mean': 0.05050505050505052, 'std': 0.02995393791713771}, 'eo': {'mean': 0.05050505050505052, 'std': 0.02995393791713771}}, {'alpha': 0.1, 'beta': 1.0, 'gamma': 10.0, 'lam': 10.0, 'accuracy': {'mean': 0.672340425531915, 'std': 0.03338610580408461}, 'dp': {'mean': 0.04733044733044735, 'std': 0.01870654933026274}, 'eo': {'mean': 0.04733044733044735, 'std': 0.01870654933026274}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 0.1, 'accuracy': {'mean': 0.6723404255319149, 'std': 0.013752283283450597}, 'dp': {'mean': 0.02813852813852813, 'std': 0.02039625267226395}, 'eo': {'mean': 0.02813852813852813, 'std': 0.02039625267226395}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 1.0, 'accuracy': {'mean': 0.6695035460992907, 'std': 0.015921946326697644}, 'dp': {'mean': 0.0443001443001443, 'std': 0.030699580507151113}, 'eo': {'mean': 0.0443001443001443, 'std': 0.030699580507151113}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 10.0, 'accuracy': {'mean': 0.6680851063829787, 'std': 0.015144791846852945}, 'dp': {'mean': 0.03261183261183263, 'std': 0.027538716649342012}, 'eo': {'mean': 0.03261183261183263, 'std': 0.027538716649342012}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 0.1, 'accuracy': {'mean': 0.6907801418439716, 'std': 0.019858156028368823}, 'dp': {'mean': 0.0500721500721501, 'std': 0.013165948126193571}, 'eo': {'mean': 0.0500721500721501, 'std': 0.013165948126193571}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 1.0, 'accuracy': {'mean': 0.6808510638297873, 'std': 0.006343455255318561}, 'dp': {'mean': 0.020779220779220797, 'std': 0.013624902461970007}, 'eo': {'mean': 0.020779220779220797, 'std': 0.013624902461970007}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6851063829787234, 'std': 0.01713907230297105}, 'dp': {'mean': 0.04040404040404041, 'std': 0.01573343079536961}, 'eo': {'mean': 0.04040404040404041, 'std': 0.01573343079536961}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 0.1, 'accuracy': {'mean': 0.6921985815602837, 'std': 0.013154068787937187}, 'dp': {'mean': 0.03160173160173161, 'std': 0.02069889443612744}, 'eo': {'mean': 0.03160173160173161, 'std': 0.02069889443612744}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 1.0, 'accuracy': {'mean': 0.6695035460992907, 'std': 0.02132382465017433}, 'dp': {'mean': 0.044300144300144326, 'std': 0.029523846756085836}, 'eo': {'mean': 0.044300144300144326, 'std': 0.029523846756085836}}, {'alpha': 1.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 10.0, 'accuracy': {'mean': 0.6638297872340425, 'std': 0.03768888015769199}, 'dp': {'mean': 0.02092352092352091, 'std': 0.02753871664934203}, 'eo': {'mean': 0.02092352092352091, 'std': 0.02753871664934203}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 0.1, 'accuracy': {'mean': 0.6709219858156028, 'std': 0.019858156028368785}, 'dp': {'mean': 0.03924963924963926, 'std': 0.014327698496360536}, 'eo': {'mean': 0.03924963924963926, 'std': 0.014327698496360536}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 1.0, 'accuracy': {'mean': 0.6680851063829787, 'std': 0.020259371428490384}, 'dp': {'mean': 0.0209235209235209, 'std': 0.02703370885465679}, 'eo': {'mean': 0.0209235209235209, 'std': 0.02703370885465679}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 0.1, 'lam': 10.0, 'accuracy': {'mean': 0.6652482269503546, 'std': 0.022156736669238734}, 'dp': {'mean': 0.031746031746031744, 'std': 0.013894525272613773}, 'eo': {'mean': 0.031746031746031744, 'std': 0.013894525272613773}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 0.1, 'accuracy': {'mean': 0.6780141843971631, 'std': 0.01713907230297105}, 'dp': {'mean': 0.042279942279942286, 'std': 0.012812325705227046}, 'eo': {'mean': 0.042279942279942286, 'std': 0.012812325705227046}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 1.0, 'accuracy': {'mean': 0.6865248226950355, 'std': 0.01134751773049647}, 'dp': {'mean': 0.02395382395382395, 'std': 0.044356123101808156}, 'eo': {'mean': 0.02395382395382395, 'std': 0.044356123101808156}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 1.0, 'lam': 10.0, 'accuracy': {'mean': 0.6893617021276596, 'std': 0.01641962681246843}, 'dp': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}, 'eo': {'mean': 0.0658008658008658, 'std': 0.05432493428375351}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 0.1, 'accuracy': {'mean': 0.6950354609929079, 'std': 0.01617270106523598}, 'dp': {'mean': 0.05310245310245308, 'std': 0.0720604226023201}, 'eo': {'mean': 0.05310245310245308, 'std': 0.0720604226023201}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 1.0, 'accuracy': {'mean': 0.6695035460992907, 'std': 0.014603730696435483}, 'dp': {'mean': 0.04516594516594515, 'std': 0.03972085166347145}, 'eo': {'mean': 0.04516594516594515, 'std': 0.03972085166347145}}, {'alpha': 10.0, 'beta': 1.0, 'gamma': 10.0, 'lam': 10.0, 'accuracy': {'mean': 0.6723404255319149, 'std': 0.017021276595744705}, 'dp': {'mean': 0.01847041847041846, 'std': 0.019412843677126226}, 'eo': {'mean': 0.01847041847041846, 'std': 0.019412843677126226}}]

"""

# %%
# first, copy-paste the log file into the field above. 
from ast import literal_eval

def parse_hparams(hp):
    d = {}
    for h in hp.split(', '):
        wv = h.split(': ')
        d[wv[0]] = wv[1]
    return d

runs = log_text.split("-----------------------------------------------")

run_results = []
for run in runs: 
    avg_results = run.split('Average training time per run')
    if len(avg_results) < 2: 
        break
    avg_results = avg_results[1].split('\n')[1:]
    run_result = {
        'hparams':parse_hparams(avg_results[0]), 
        'results': literal_eval(avg_results[1].split('Average results: ')[1])}
    run_results.append(run_result)

# %%
# you can access the results like this:
run_results[3]['results']['acc']['mean']
# Out:
# 0.6709219858156028

# %%
# print results for one of the runs
import json
print(json.dumps(run_results[0], indent=4))
# Out:
# {
#     "hparams": {
#         "alpha": "0.1",
#         "beta": "1.0",
#         "gamma": "0.1",
#         "lam": "0.1"
#     },
#     "results": {
#         "acc": {
#             "mean": 0.6836879432624113,
#             "std": 0.02269503546099294
#         },
#         "dp": {
#             "mean": 0.05064935064935065,
#             "std": 0.054680806587304745
#         },
#         "eo": {
#             "mean": 0.042293233082706785,
#             "std": 0.02166144404644805
#         }
#     }
# }

# %%
# this is for something else, don't mind this

# Avg results: acc: 0.6553 std: 0.0035 dp: 0.0049 std: 0.0043 eo: 0.0506 std: 0.0071
# Avg results: acc: 0.7021 std: 0.0179 dp: 0.1274 std: 0.0565 eo: 0.1598 std: 0.0654
# Avg results: acc: 0.6667 std: 0.0000 dp: 0.0087 std: 0.0000 eo: 0.0113 std: 0.0000
# Avg results: acc: 0.6610 std: 0.0028 dp: 0.0061 std: 0.0078 eo: 0.0827 std: 0.0000
# Avg results: acc: 0.6908 std: 0.0035 dp: 0.0322 std: 0.0049 eo: 0.0244 std: 0.0000

# Avg results: acc: 0.6936 std: 0.0053 dp: 0.0328 std: 0.0335 eo: 0.0570 std: 0.0491
# Avg results: acc: 0.6681 std: 0.0083 dp: 0.0121 std: 0.0037 eo: 0.0237 std: 0.0065
# Avg results: acc: 0.6837 std: 0.0035 dp: 0.0455 std: 0.0064 eo: 0.0148 std: 0.0071
# Avg results: acc: 0.6695 std: 0.0057 dp: 0.0203 std: 0.0073 eo: 0.0346 std: 0.0095


inp = """
Avg results: acc: 0.6105 std: 0.0113 dp: 0.0631 std: 0.0066 eo: 0.0607 std: 0.0081
Avg results: acc: 0.6029 std: 0.0017 dp: 0.0805 std: 0.0014 eo: 0.0870 std: 0.0024
Avg results: acc: 0.6155 std: 0.0024 dp: 0.0551 std: 0.0058 eo: 0.0542 std: 0.0087
Avg results: acc: 0.6152 std: 0.0059 dp: 0.0513 std: 0.0076 eo: 0.0389 std: 0.0060
"""
results = []
for sentence in inp.split('\n'):
    if len(sentence) == 0:
        continue
    values = sentence.split(" ")[1::2][1:]
    s = ""
    for i in range(3):
        s += values[i*2] + " (" + values[i*2+1] + ")    "
    results.append(s)
    
for res in results:
    print(res)
# Out:
# 0.6105 (0.0113)    0.0631 (0.0066)    0.0607 (0.0081)
# 0.6029 (0.0017)    0.0805 (0.0014)    0.0870 (0.0024)
# 0.6155 (0.0024)    0.0551 (0.0058)    0.0542 (0.0087)
# 0.6152 (0.0059)    0.0513 (0.0076)    0.0389 (0.0060)

# %% [markdown]
# # Pareto Front

# %%
import os
from ast import literal_eval
import json

experiment_path = 'experiments/NBA_grid_search/'

filenames = os.listdir(file_path)
results = []

for filename in filenames:
    if filename.startswith('output-'):
        with open(experiment_path + filename) as f:
            # get hyperparameters from log
            filename_split = filename.split('-')
            alpha = filename_split[1][1:]
            beta  = filename_split[2][1:]
            gamma = filename_split[3][1:]
            lam   = filename_split[4][1:-4]
            
            # get results from log            
            log_text = f.read()
            avg_results_text = log_text.split('Average results: ')[1][:-1]
            avg_results = literal_eval(avg_results_text)
            
            # append the avg results dictionary to a list
            results.append({
                'alpha': alpha,
                'beta': beta,
                'gamma': gamma,
                'lam': lam,
                **avg_results,
            })
            
            
            
print(json.dumps(results[2], indent=4))
# Out:
# {
#     "alpha": "1.0",
#     "beta": "1.0",
#     "gamma": "0.1",
#     "lam": "10.0",
#     "acc": {
#         "mean": 0.6709219858156028,
#         "std": 0.01654170750310726
#     },
#     "dp": {
#         "mean": 0.03607503607503608,
#         "std": 0.016703949354675642
#     },
#     "eo": {
#         "mean": 0.05864661654135338,
#         "std": 0.05026429666746944
#     }
# }

# %%
# find the setting with the best accuracy

best_acc = -1
best_index = -1
for i, res in enumerate(results):
    acc = res['acc']['mean']
    if acc > best_acc:
        best_index = i
        best_acc = acc
results[best_index]
# Out:
# {'alpha': '1.0',
#  'beta': '1.0',
#  'gamma': '1.0',
#  'lam': '10.0',
#  'acc': {'mean': 0.70354609929078, 'std': 0.005307315442232549},
#  'dp': {'mean': 0.04747474747474749, 'std': 0.025959591949030227},
#  'eo': {'mean': 0.045488721804511266, 'std': 0.01950363476113937}}

# %%
# find the pareto front ACC-DP

# %%
import matplotlib.pyplot as plt
import numpy as np

def find_pareto_front(results, metric1, metric2):
    """In this method, the first metric is maximized, the second is minimized!!"""
    pareto_front = []
    for i in range(len(results)):
        is_dominated = False
        for j in range(len(results)):
            if i == j: continue
            if results[i][metric1]['mean'] <= results[j][metric1]['mean'] and \
                results[i][metric2]['mean'] >= results[j][metric2]['mean']:
                is_dominated = True

        if not is_dominated:
            pareto_front.append(results[i])  
            
    return pareto_front

def plot_pareto(results, metric, title, show_all):
    """This only properly works if metric2 is acc"""
    
    # find the pareto front
    pareto_front = find_pareto_front(results, 'acc', metric)

    # collect all the points (also ones not in the front)
    all_points = np.zeros((27,2))
    for i in range(len(results)):
        all_points[i][0] = results[i]['acc']['mean']
        all_points[i][1] = results[i][metric]['mean']
    
    # create the xs and ys for the plot
    arr = np.zeros((len(pareto_front), 2))
    for i, r in enumerate(pareto_front):
        arr[i][0] = r[metric]['mean']
        arr[i][1] = r['acc']['mean']
    arr = np.sort(arr, axis=0)

    # create the plot
    plt.plot(arr[:,0], arr[:,1])
    plt.xlabel(metric)
    plt.ylabel('acc')
    plt.title(title)
    if show_all:
        plt.scatter(all_points[:,1],all_points[:,0], color='red')
    plt.show()

# %%
plot_pareto(results, 'dp', 'Pareto front Accuracy - DP', show_all=True)

# %%
plot_pareto(results, 'eo', 'Pareto front Accuracy - EO', show_all=True)
